# %%
from bs4 import BeautifulSoup
import requests

url="https://www.dabur.com/amp/in/en-us/about/science-of-ayurveda/herbal-medicinal-plants"
source=requests.get(url)

soup = BeautifulSoup(source.text,'html')
tags = [tag.name for tag in soup.find_all()]
print(tags)
print((soup.find('title')).text)
# Out:
# ['html', 'head', 'meta', 'meta', 'meta', 'link', 'script', 'link', 'meta', 'script', 'script', 'script', 'script', 'script', 'style', 'noscript', 'style', 'style', 'title', 'body', 'amp-analytics', 'amp-analytics', 'script', 'amp-sidebar', 'button', 'amp-accordion', 'section', 'h4', 'span', 'div', 'ul', 'li', 'h3', 'li', 'a', 'li', 'a', 'li', 'a', 'li', 'a', 'li', 'a', 'li', 'a', 'ul', 'li', 'h3', 'li', 'a', 'li', 'a', 'li', 'a', 'li', 'a', 'ul', 'li', 'h3', 'li', 'a', 'li', 'a', 'li', 'a', 'li', 'a', 'li', 'a', 'li', 'a', 'ul', 'li', 'h3', 'li', 'a', 'ul', 'li', 'h3', 'li', 'a', 'li', 'a', 'li', 'a', 'ul', 'li', 'h3', 'li', 'a', 'li', 'a', 'li', 'a', 'li', 'a', 'li', 'a', 'ul', 'li', 'h3', 'li', 'a', 'li', 'a', 'li', 'a', 'li', 'a', 'li', 'a', 'ul', 'li', 'h3', 'li', 'a', 'li', 'a', 'ul', 'li', 'h3', 'li', 'a', 'section', 'h4', 'span', 'div', 'ul', 'li', 'h3', 'li', 'a', 'li', 'a', 'li', 'a', 'li', 'a', 'ul', 'li', 'h3', 'li', 'a', 'li', 'a', 'li', 'a', 'li', 'a', 'li', 'a', 'ul', '
# ...

# %%
p = soup.find_all('p')
n=len(p)
print(n)
# Out:
# 11

# %%
heading_tags = ["h1", "h2", "h3","h4","h5","h6"]
head = soup.find_all(heading_tags)
n1=len(head)
print(n1)
# Out:
# 84

# %%
div = soup.find_all('div')
n2=len(div)
print(n2)
# Out:
# 300

# %%
table = soup.find_all('tr')
n3=len(table)
print(n3)
# Out:
# 58

# %%
table = soup.find_all('a')
n4=len(table)
print(n4)
# Out:
# 367

# %%
table = soup.find_all('h1')
n5=len(table)
print(n5)
# Out:
# 1

# %%
table = soup.find_all('h2')
n6=len(table)
print(n6)
# Out:
# 3

# %%
table = soup.find_all('h3')
n7=len(table)
print(n7)
# Out:
# 73

# %%
if(n1>0):
    heading_tags = ["h1", "h2", "h3"]
    for tags in soup.find_all(heading_tags):
        print(tags.name + ' -> ' + tags.text.strip())
        
if(n2>0):
    content=soup.find_all("div")
    
    for i in content:
        print(i.text)
        
if(n>0):
    contents=soup.find_all("p")
    
    for i in contents:
        print(i.text)

if(n3>0):
    overview=soup.find_all('table')

    for z in overview:
        print(z.text)
# Out:
# h3 -> About Us
# h3 -> Leadership
# h3 -> Dabur Product websites
# h3 -> Our Herbal Kingdom
# h3 -> DABUR GROUP OF COMPANIES
# h3 -> Utilities
# h3 -> Contact Information
# h3 -> Private Label Business
# h3 -> Overseas Distribution
# h3 -> Hair Oils
# h3 -> Shampoos
# h3 -> Health Supplements
# h3 -> Digestives
# h3 -> Skin Care
# h3 -> Foods
# h3 -> Oral Care
# h3 -> Otc & Ethicals
# h3 -> Home Care
# h3 -> Guar Gum
# h3 -> Share Information
# h3 -> Financial Information
# h3 -> Corporate Governance
# h3 -> Investor Information
# h3 -> Dabur in News
# h3 -> Press Releases
# h3 -> Events
# h3 -> Accolades
# h3 -> Gallery
# h3 -> Caution Notice
# h3 -> Great Place to Work
# h3 -> Campus Bridge
# h3 -> Find a Job
# h3 -> About Us
# h3 -> Leadership
# h3 -> Dabur Product websites
# h3 -> Our Herbal Kingdom
# h3 -> DABUR GROUP OF COMPANIES
# h3 -> Utilities
# h3 -> Contact Information
# h3 -> Private Label Business
# h3 -> Overseas Distribution
# h3 -> Hair Oils
# h3 -> Shampoos
# ...

# %%
def number_to_string(argument):
    s=argument
    if((s>= 0) and (s<= 8)):
        if(s==0):
            print((soup.find('title')).text)
        elif(s==1):
            if(n3>0):
                overview=soup.find_all('table')

                for z in overview:
                    print(z.text)
            
            else:
                print("No content available")

        elif(s==2):
            if(n>0):
                contents=soup.find_all("p")

                for i in contents:
                    print(i.text)

            else:{
                print("No content available")
            }

        elif(s==3):
            if(n2>0):
                content=soup.find_all("div")

                for i in content:
                    print(i.text)

            else:
                print("No content available")

        elif(s==4):
            if(n5>0):
                heading_tags = ["h1"]
                for tags in soup.find_all(heading_tags):
                    print(tags.name + ' -> ' + tags.text.strip())

            else:{
                print("No content available")
            }

        elif(s==5):
            if(n6>0):
                heading_tags = ["h2"]
                for tags in soup.find_all(heading_tags):
                    print(tags.name + ' -> ' + tags.text.strip())

            else:
                print("No content available")
            
        elif(s==6):
            if(n7>0):
                heading_tags = ["h3"]
                for tags in soup.find_all(heading_tags):
                    print(tags.name + ' -> ' + tags.text.strip())

            else:{
                print("No content available")
            }
        elif(s==7):
            if(n4>0):
                contents=soup.find_all("a")

                for i in contents:
                    print(i.text)

            else:{
                print("No content available")
            }

        else:
            if(n1>0):
                heading_tags = ["h1", "h2", "h3","h4","h5","h6"]
                for tags in soup.find_all(heading_tags):
                    print(tags.name + ' -> ' + tags.text.strip())

            else:{
                print("No content available")
            }
    
    else:
        print("INVALID")        
 
if __name__ == "__main__":
    print("for Title content enter - 0")
    print("for table tag content enter - 1")
    print("for paragraph tag content enter - 2")
    print("for div tag content enter - 3")
    print("for h1 tag content enter - 4")
    print("for h2 tag content enter - 5")
    print("for h3 tag content enter - 6")
    print("for a tag content enter - 7")
    print("for all the heading tag content enter - 8")
    argument = int(input("enter the valid tag number from above: "))
    number_to_string(argument)
    print(argument)
# Out:
# for Title content enter - 0
# for table tag content enter - 1
# for paragraph tag content enter - 2
# for div tag content enter - 3
# for h1 tag content enter - 4
# for h2 tag content enter - 5
# for h3 tag content enter - 6
# for a tag content enter - 7
# for all the heading tag content enter - 8
# enter the valid tag number from above: 7
# Dabur Corporate Profile
# History
# Vision & Mission
# Policies
# Ayurveda
# Knowledge Center
# Our Founder
# Burman Family Tree
# Meet the CEO
# Board of Directors
# Dabur Chyawanprash
# Dabur Lal Tail
# Dabur Woman
# Dabur Mediclub
# Odonil
# Odomos Protect
# A Greener Tomorrow
# NewU
# Hobby
# Namaste
# Caution Notice
# Dealer Locator
# Know your Prakriti
# Consult a Doctor
# Download Panchang App
# Addresses
# Branch Offices
# Factories
# Overseas Offices
# Subsidiaries
# Private Label
# Contact Info
# Apply for Distribution
# Amla
# Vatika
# Almond
# Anmol Gold Coconut Oil
# Almond Shampoo
# Vatika Health Shampoo
# ...

# %%
def number_to_string(argument):
    s=argument
    if((s>= 0) and (s<= 8)):
        if(s=0):
            print((soup.find('title')).text)
        else if(s=1):
            if(n3>0):
                overview=soup.find_all('table')

                for z in overview:
                    print(z.text)
            
            else:
                print("No content available")

        case "2":
            if(n>0):
                contents=soup.find_all("p")

                for i in contents:
                    print(i.text)

            else:{
                print("No content available")
            }

        case "3":
            if(n2>0):
                content=soup.find_all("div")

                for i in content:
                    print(i.text)

            else:
                print("No content available")

        case "4":
            if(n5>0):
                heading_tags = ["h1"]
                for tags in soup.find_all(heading_tags):
                    print(tags.name + ' -> ' + tags.text.strip())

            else:{
                print("No content available")
            }

        case "5":
            if(n6>0):
                heading_tags = ["h2"]
                for tags in soup.find_all(heading_tags):
                    print(tags.name + ' -> ' + tags.text.strip())

            else:
                print("No content available")
            
        case "6":
            if(n7>0):
                heading_tags = ["h3"]
                for tags in soup.find_all(heading_tags):
                    print(tags.name + ' -> ' + tags.text.strip())

            else:{
                print("No content available")
            }
        case "7":
            if(n4>0):
                contents=soup.find_all("a")

                for i in contents:
                    print(i.text)

            else:{
                print("No content available")
            }

        case "8":
            if(n1>0):
                heading_tags = ["h1", "h2", "h3","h4","h5","h6"]
                for tags in soup.find_all(heading_tags):
                    print(tags.name + ' -> ' + tags.text.strip())

            else:{
                print("No content available")
            }
            
               
        case default:
            print("INVALID")
            
 
if __name__ == "__main__":
    print("for Title content enter - 0")
    print("for table tag content enter - 1")
    print("for paragraph tag content enter - 2")
    print("for div tag content enter - 3")
    print("for h1 tag content enter - 4")
    print("for h2 tag content enter - 5")
    print("for h3 tag content enter - 6")
    print("for a tag content enter - 7")
    print("for all the heading tag content enter - 8")
    argument = int(input("enter the valid tag number from above: "))
    number_to_string(argument)
    print(argument)
